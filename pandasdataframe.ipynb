# %%
import numpy as np
import pandas as pd
import json_lines

# %%
regs = pd.DataFrame()
counter = 0

with open('de_companies_ocdata.jsonl', 'rb') as f:

    for c in range(counter, counter + 10000):
        for e in json_lines.reader(f):

# %%
regs = []

with open('de_companies_ocdata.jsonl', 'rb') as f:
    for item in json_lines.reader(f):
        regs.append(item)
        if len(regs)>5000:
            break

# %%
data = pd.DataFrame.from_dict(regs, orient='columns', dtype=None, columns=None)
data = data.set_index("name")

# %%
data
# Out:
#                                                                                        all_attributes  \
# name
# olly UG (haftungsbeschränkt)                        {'_registerArt': 'HRB', '_registerNummer': '15...
# BLUECHILLED Verwaltungs GmbH                        {'_registerArt': 'HRB', '_registerNummer': '81...
# Mittelständische Beteiligungsgesellschaft Breme...  {'_registerArt': 'HRB', '_registerNummer': '18...
# Albert Barufe GmbH                                  {'_registerArt': 'HRB', '_registerNummer': '45...
# ITERGO Informationstechnologie GmbH                 {'_registerArt': 'HRB', '_registerNummer': '37...
# Rheinbahn AG                                        {'_registerArt': 'HRB', '_registerNummer': '56...
# Verwaltung IFÖ Zweite Immobilienfonds für Öster...  {'_registerArt': 'HRB', '_registerNummer': '82...
# AWS Personalmarketing GmbH                          {'_registerArt': 'HRB', '_registerNummer': '29...
# ...

# %%
test_list = []
for i in range(20000):
    test_list.append(i)

# %%
def iterate_step(li):
    counter = 0
    
    chunk = []
    
    for e in li:
        chunk =(e)
    counter += 1
    
    if counter >= 300:
        print(newlist)
        yield ???

# %%
import itertools

def counter(number):
    counter += 10000
    yield counter

# %%
a = counter(0)
next(a)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-21-38cc9caee618> in <module>()
#       1 a = counter(0)
# ----> 2 next(a)
#
# <ipython-input-19-92890ca9567c> in counter(number)
#       2
#       3 def counter(number):
# ----> 4     counter += 10000
#       5     yield counter
#
# UnboundLocalError: local variable 'counter' referenced before assignment

# %%
for line in itertools.islice(test_list, 10, 20):
     print(line)
